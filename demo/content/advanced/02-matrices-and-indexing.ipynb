# %% [markdown]
# # Matrices and indexing
#
# Matrices are the core numbl data type. This notebook covers construction,
# reshaping, and MATLAB-style indexing.

# %% [markdown]
# ## Constructing matrices

# %%
Z = zeros(2, 3)
O = ones(2)
I = eye(3)
M = magic(4)

# %% [markdown]
# ## Ranges with the colon operator

# %%
1:5
0:0.25:1
10:-2:0

# %% [markdown]
# ## Size and reshaping

# %%
A = reshape(1:12, 3, 4)
size(A)
numel(A)
A'

# %% [markdown]
# ## Concatenation

# %%
[1 2; 3 4]
[ones(2, 2), zeros(2, 2)]

# %% [markdown]
# ## Indexing: subscripts, ranges, and `end`

# %%
M = magic(4);
M(2, 3)
M(:, 1)'
M(end, :)
M(1:2, 3:4)

# %% [markdown]
# ## Linear and logical indexing

# %%
M = magic(4);
M(5)
M(M > 10)'

# %% [markdown]
# ## Assignment, growth, and deletion

# %%
x = 1:5;
x(2) = 20;
x(8) = 99;
x

# %%
y = 1:6;
y(2:3) = [];
y
