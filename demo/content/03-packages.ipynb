% %% [markdown]
% # Installing packages — still no server
%
% numbl ships with `mip`, a package manager for MATLAB-syntax libraries.
% Packages are fetched from GitHub releases and cached in your browser's
% IndexedDB, so the download happens once.
%
% The first cell you run in a session also bootstraps the engine, so expect a
% short delay (progress is printed).

% %%
mip load --install chebfun

% %%
% Chebfun: numerical computing with functions
x = chebfun('x', [0 4]);
f = sin(x.^2);
r = roots(f);
fprintf('sin(x^2) has %d roots in [0, 4]\n', numel(r));

% %%
% Evaluate the chebfun on a grid and mark its roots
xx = linspace(0, 4, 400);
plot(xx, f(xx));
hold on;
plot(r, f(r), 'ro');
hold off;
title('sin(x^2) and its roots');
